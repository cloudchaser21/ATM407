# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://github.com/brianmapes/ATM407/blob/master/images/LMT_1.5_MERRA.png?raw=true" alt="Thermal wind exercise image" style="height: 200px;"></div>
#
#
# <h1>Rossby waves: Exercise 1.5 of Lackmann-Mapes-Tyle manual</h1>
# <h3>ATM 407, University of Miami</h3>
#
# ### Activities
# 1. <a href="#Exercise1">Do a little bit of math about Rossby waves</a>
# 1. <a href="#Exercise2">Load bundle, show basic evolution</a>
# 1. <a href="#Exercise3">Illustrate the concept of Rossby waves with an image from the Web</a>
# 1. <a href="#Exercise4">LMT 1.5a</a>
# 1. <a href="#Exercise5">LMT 1.5b</a>
# 1. <a href="#Exercise6">LMT 1.5c</a>
# 1. <a href="#Exercise7">LMT 1.5d</a>
# 1. <a href="#Exercise8">LMT 1.5e</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">
#
# ### Background
# Recall the spirit of the *vorticity equation*: It eliminates the PGF from the horizontal momentum equations.  Let's ignore friction for now.
#
# * Horizontal acceleration equation (F=ma):
# $$ \frac{du}{dt} = - \frac{\partial \Phi}{\partial x} + fv $$
#
# $$ \frac{dv}{dt} = - \frac{\partial \Phi}{\partial y} - fu $$
#
# * Eliminate $\Phi$ by subtracting the y derivative of the u equation from the x derivative of the v equation:
#
# $$ \frac{d}{dt}(\zeta_{abs}) = 0 - \zeta_{abs} (\nabla \cdot V)$$
#
# * Recall that $ \zeta_{abs} = \zeta_{rel} + f $, where f is *planetary vorticity*.
#
# * We neglect the divergence term, or view it (vaguely) as one aspect of the "forcing" of Rossby waves.
#
# $$ \frac{d}{dt}(\zeta_{abs}) = 0 $$
#
#
#
# * In our Irma-related exercise, we focused on the advection of $\zeta_{rel}$ by winds circulating around patches of $\zeta_{rel}$.
#
# * Here we instead consider the *Rossby wave* limiting case: considering **ONLY** the horizontal advection of planetary vorticity, again by winds $\vec V_{hor}$ circulating around patches of $\zeta_{rel}$.
#
# $$ \frac{\partial}{\partial t}(\zeta_{rel}) = -\vec V_{hor} \cdot \nabla f$$
#
#
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise1"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 1</b>:
#      <ul>
#       <li>Express the right hand side of the final equation above in component form.</li>
#       <li>Enter it in the cell below, learning how to markdown equations from the cell above. </li>
#       <li>Use the symbol $\beta = df/dy$ to make your answer more compact. </li>
#
#     </ul>
# </div>

# %% [markdown]
# ## Exercise 1 Answer. The Rossby wave governing equation is:
#
# $$ \frac{\partial}{\partial t}(\zeta_{rel}) = ... $$
#
# $$ \equiv ... (\beta) ... $$

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise2"></a>
# ## Exercise 2: Load the LMT_1.5 IDV bundle and capture a basic view
#
# automatically, or manually

# %%
# %reload_ext drilsdown 
# You must do this to activate the IDV-Notebook connection. 
# Then either use the control panel for the automatic approach, or load the IDV bundle manually.
# Out:
# tempfile.tempdir = '/var/folders/ct/x4nctptn38d042_shnyy5zr00000gn/T'
# tempfile.gettempdir() = '/var/folders/ct/x4nctptn38d042_shnyy5zr00000gn/T'
# No IDV_HOME environment variable set
# You can set the path to the IDV script with:
# from drilsdown import Idv
# Idv.setPath("/path to idv executable")
# #e.g.:
# Idv.setPath("/Applications/IDV_5.3u1/runIDV")

# %% [markdown]
# <div class="alert alert-success">
#     <b>EXERCISE 2</b>:
#      <ul>
#       <li> Read the assignment in the LMT manual, exercise 1.5.
#       </li>
#       <li>
#       ** Capture the initial view, and explain in the caption what it shows. What is the red shading? What are the solid and dashed contours that fall across North America? **
#       </li>
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise2
# Out:
# tempfile.tempdir = '/var/folders/ct/x4nctptn38d042_shnyy5zr00000gn/T'
# tempfile.gettempdir() = '/var/folders/ct/x4nctptn38d042_shnyy5zr00000gn/T'
# IDV exectuable does not exist:
# /Users/Nick/Applications/IDV_5.4/runIDV

# %%
from drilsdown import Idv
Idv.setPath("/Users/Nick/Applications/IDV_5.4/runIDV")

# %% [markdown]
# ## Exercise 2 caption/answer:
# The red shading refers to magnitude of absolute vorticity distribution. The dashed contours refer to lines of latitude contoured at 40 degree intervals. The solid red contour refers to absolute vorticity at 250 mb of magnitude 1x10^-4 s^-1

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise3"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 3</b>:
#      <ul>
#
#       <li>**Find a good image on the Web illustrating the mechanism of Rossby waves (**
#       </li>
#
#       <li>**Does the cold or warm air advance as you anticipated from Exercise 3a? Does the sounding show a decrease of temperature with time?**
#       </li>
#
#       <li>**What does this mean about the terms in the First Law? Is the horizontal advection term the dominant effect?**
#       </li>
#
#     </ul>
# </div>

# %%
# Image from Web illustrating how Rossby waves work. 
# Make sure your URL points all the way to an image file, not to a code URL. 
# On any browser image, right-click and select "Open image in new tab", then capture that URL. 

from IPython.display import Image
Image("https://media1.britannica.com/eb-media/29/101929-004-0AC1F903.jpg")

# %% [markdown]
# ## Answer to exercise 3: the Web image illustrates...
#
# This image describes perturbations (IE Rossby Waves) within a larger flow regime (IE polar vortex). Initially, flow is relatively consistent around the vortex. However, as smaller scale pressure gradients begin to form and intensify, perturbations take place within the larger flow regime (Rossby Waves). The magnitude of these waves increases until a portion "breaks off" in the form of a local mass of cold air. The original, equilibrium state of flow then returns. This process will repeat itself continuously.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise4"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 4</b>:
#      <ul>
#
# <li>**
#      a) Explore the displays. Check the boxes to display 250-hPa height (global hgt), and Eddy height (where eddy is de ned as deviations from the zonal average around the whole planet along each latitude line). Step forward to 1200 UTC 25 September.
#       **</li>
#
# <li>**
#      Capture images to show how the eddy height field relates to the north–south excursions of the solid red contour. Describe the relationshop between the northward-moving Tropical Cyclone Malakas and the upper-level ridge located to the north and east of it at this time.
#       **</li>
#
#
#     </ul>
# </div>

# %%
from IPython.display import Image
Image("/Users/Nick/Documents/SCHOOL/SEN/407/malaka.jpg")

# %%
# Your images 
#%makeImage -cKaption ExerciseN_additional_label

# %% [markdown]
# ## Exercise 4 answer:
#
# Regions of large 250 hpa height gradient typically align with the red 250 mb absolute vorticity contour. Regions in which the 250 mb absolute vorticity contour is located more northward are typically associated with regions of positive eddy height (IE ridges - areas of high pressure) whereas regions where the 250 mb absolute vorticity contour is located more southhward are typically associated with regions of negative eddy height (IE troughs - areas of low pressure).

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise5"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 5</b>:
#      <ul>
#
# <li>**
#      b) Step the time ahead by a few more days to identify a time with a large-amplitude downstream wave (trough–ridge couplet), and step forward and backward in time
# to gain a sense of the upper wave evolution. Estimate the longitude of the ridge that forms immediately downstream of Malakas at 1200 UTC 25 September, and track this feature until 0000 UTC 28 September. Use the readout of Longitude of the cursor at the bottom of the IDV window.
#       **</li>
#
# <li>**
#      Estimate the eastward speed of this ridge, utilizing your knowledge of the spacing of longitude lines at the latitude in question. State any approximations or sources of possible error in your calculation.
#       **</li>
#
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise5
# Out:
# tempfile.tempdir = '/var/folders/cx/744cq3h94zq66_v0ms6wg8m40000gn/T'
# tempfile.gettempdir() = '/var/folders/cx/744cq3h94zq66_v0ms6wg8m40000gn/T'

# %%
# Your images 
#%makeImage -cKaption ExerciseN_additional_label

# %%
# Your movies 
#%makeMovie

# %% [markdown]
# ## Exercise 5 answer:
#
# I utilized a rough approximation of 55 nm/degree longitude. With the ridge traversing approximately 52 degrees in 60 hours, this equates to approximately 2860 nm in 60 hours which equates to roughly 55 mph, an eastward speed that is relatively acceptable, given that the pressure level in question is 250 mb.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise6"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 6</b>:
#      <ul>
#
# <li>**
#      c) Notice that the amplitude of the ridge weakens by the end of the time period speci ed (0000 UTC 28 September).  is indicates that energy is dispersing downstream at
# the Rossby wave group velocity, a topic discussed further in Chapter 2 of MSM (see its Fig. 2.20 for example). As discussed in section 1.5.3 of the MSM text, a useful and compact graphical means of representing Rossby wave activity is the longitude–time section or Hovmöller diagram (Fig. 1.4 below).
#       **</li>
#
# <li>**
#      Utilize Fig. 1.4 to locate the ridge associated with Malakas (which you tracked in b.) at the 500-hPa level. Compute the phase speed of this ridge, which is the slope of the orange streak on this diagram. Compare this to the value you estimated in b.) Is it consistent? Discuss the sources of uncertainty in these calculations.
#       **</li>
#
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise6
# Out:
# tempfile.tempdir = '/var/folders/cx/744cq3h94zq66_v0ms6wg8m40000gn/T'
# tempfile.gettempdir() = '/var/folders/cx/744cq3h94zq66_v0ms6wg8m40000gn/T'

# %%
# Your images 
#%makeImage -cKaption ExerciseN_additional_label

# %%
# Your movies 
#%makeMovie

# %% [markdown]
# ## Exercise 6 answer:
#
# Replace this text with your own

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise7"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 7</b>:
#      <ul>
#
# <li>**
#      d) Figure 1.4 indicates a series of alternating troughs and ridges that appear downstream of Malakas. Sketch a line approximately connecting a set of maximum amplitude features in this “wave train” of troughs and ridges.
#       **</li>
#
# <li>**
#      Compute the group velocity implied by this wave train (or “packet”) based on the slope of your line. Which is the larger eastward speed, the phase or group velocity?
#       **</li>
#
#
#     </ul>
# </div>

# %%
# Your image 
# %makeImage -caption Exercise7
# Out:
# tempfile.tempdir = '/var/folders/cx/744cq3h94zq66_v0ms6wg8m40000gn/T'
# tempfile.gettempdir() = '/var/folders/cx/744cq3h94zq66_v0ms6wg8m40000gn/T'

# %%
# Your images 
#%makeImage -cKaption ExerciseN_additional_label

# %%
# Your movies 
#%makeMovie

# %% [markdown]
# ## Exercise 7 answer:
#
# Replace this text with your own

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise8"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 8</b>:
#      <ul>
#
# <li>**
#      In the IDV, rotate the globe to see remote regions (over North America) more clearly.
# How far downstream in the midlatitude jet stream do you think you can detect
# waves emitted by Malakas? Make the case using an image sequence you capture, annotating the features you feel are linked. Compare these results with the Hovmöller (time–longitude) plot in Fig. 1.4, and discuss the comparison.
#       **</li>
#
# <li>**
#      Examine Fig. 1.5
# (which is taken from Figs. 2 and 3 of Torn and Hakim), an average of many cases.  The Web link to this paper is http://dx.doi.org/10.1175/MWR-D-14-00006.1. Capture a key image from the paper, and relate your findings to that composite, which will help ensure you are not over-interpreting the data in this one case (since Malakas was not the only "Rossby wave source"  event or factor in the hemisphere causing troughs and ridges to develop over North America). In the IDV bundle, can you identify a source for the following Pacific “wave train” (lower part of Fig. 1.4), after the Malakas-triggered events?
#       **</li>
#
#     </ul>
# </div>

# %%
# Image from Torn and Hakim paper
from IPython.display import Image
Image("http:// ... ")

# %%
# Your image 
# %makeImage -caption Exercise8
# Out:
# tempfile.tempdir = '/var/folders/cx/744cq3h94zq66_v0ms6wg8m40000gn/T'
# tempfile.gettempdir() = '/var/folders/cx/744cq3h94zq66_v0ms6wg8m40000gn/T'

# %%
# Your images 
#%makeImage -cKaption ExerciseN_additional_label

# %%
# Your movies 
#%makeMovie

# %% [markdown]
# ## Exercise 8 answer:
#
# Replace this text with your own

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">
