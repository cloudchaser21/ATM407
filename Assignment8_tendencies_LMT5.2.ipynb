# %% [markdown]
# <a name="top"></a>
#
# <div style="width:1000 px">
#
# <div style="float:right; width:300 px"><img src="https://github.com/brianmapes/ATM407/blob/master/images/LMT_5.4.png?raw=true" alt="Heating tendencies LMT_5.4 exercise image" style="height: 200px;"></div>
#
#
# <h1>Assignment 8: Heating rates in a midlatitude cyclone</h1>
# <h3>ATM 407, University of Miami</h3>
#
# * To use these Jupyter notebooks, you need to have installed all this:
# https://brianmapes.github.io/EarthCube-DRILSDOWN/ )
#
#
# ### Activities
# 1. <a href="#Exercise1">Some math about it</a>
# 1. <a href="#Exercise2">Load an IDV bundle</a>
# 1. <a href="#Exercise3">Answer the book's LMT_5.4 questions</a>
# 1. <a href="#Exercise4">Use LMT_5.4_MERRA_1979-2015 to make the same bundle for YOUR case.</a>
# 1. <a href="#Exercise5">Answer the mose interesting part for YOUR case.</a>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">

# %% [markdown]
# ### Background
# Remember, for the test you will memorize and write the primitive equations:
# 1. Horizontal acceleration equation (F=ma):
# $$ \frac{d}{dt} \vec V_h = f \vec V_h \times \hat k  - \vec \nabla_p \Phi +\vec F_r  $$
# or, in component form,
# $$ \frac{du}{dt} = fv  - \frac{\partial \Phi}{\partial x} +F_{rx} $$
# $$ \frac{dv}{dt} = -fu - \frac{\partial \Phi}{\partial y} +F_{ry} $$
#
# 1. Vertical acceleration equation (aka Hydrostatic balance):
# $$ \frac {\partial \Phi}{\partial p} = - \alpha \equiv -\frac{1}{\rho} = \frac{RT}{p} = \frac{R\theta}{p} (\frac{T}{\theta})$$
# 1. Mass continuity:
# $$ 0 = \frac {\partial u}{\partial x} + \frac {\partial v}{\partial y}  + \frac {\partial \omega}{\partial p} $$
# 1. First Law of thermodynamics:
# $$ \frac {d \theta}{dt} = Q_\theta $$
# where $Q_\theta$, the heating rate in $\theta$ units, is related to dT/dt_{diabatic} = Q (in W/kg units) by:
# $$ Q_\theta = Q/C_p\frac{\theta}{T} $$
#
#
# #### For this exercise, let's focus on the First Law in the form used by atmosphere models (Eulerian grids).
#
# $$ \frac {\partial \theta}{\partial t} = -V \cdot \nabla \theta + Q_\theta  = Q_{dyn} + Q_{phys}$$
#
# Or, more to the point for digital atmospheric models with a finite timestep dt,
#
# $$ \theta_{future}(x,y,p) = \theta_{present} + dt \frac{(Q_{dyn} + Q_{phys} )} {C_p} \frac{\theta}{T}$$
#
# Save room in your brain for the concept of $Q_{ana}$, the *analysis tendency*, which is *the tendency required to make a model evolve in time as the world was observed to evolve in time.* (That is, *the sum of all errors in model estimates of Q{phys} and Q_{dyn} from all its derivatives and combinations of its state variables).
#
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise1"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 1</b>:
#      <ul>
#
# <li>**What is $\frac{\theta}{T}$ in the above casting of the equations? ** Show that it involves only the coordinate variable $p$.</li>
#
# <li>We can express $Q$ into the 3 physical forms of heat transfer (from fundamental physics): *radiation, conduction, convection, and chemical reaction.*</li>
#
# $$Q_{phys} = Q_{rad} +  Q_{surface} + Q_{turb} + Q_{chem}$$
#
# <li>**Explain in words how these map onto the column heating physics in atmosphere model:**</li>
#
# $$Q_{phys} = Q_{LW} +  Q_{SW} + Q_{SHF} + Q_{PBL \ diffusion} +Q_{gridscale \ cond-evap} + Q_{subgrid \ cumulus \ convection} +Q_{frictional \ dissipation}$$
#
# <li>**Explain how the profile of longwave radiation $Q_{LW}$ relates to the profile of cloudiness.**</li>
#
#     </ul>
# </div>

# %% [markdown]
# ## Exercise 1 Answer:
# ### First question bullet:
#
# $\frac{\theta}{T}$ = ???
#
#
# ### Second question (third bullet):
# 1. Q_LW is purely **radiative** (LW="longwave", the infrared radiation emitted by parts of the Earth system).
# 2. Q_SW is purely **radiative**
# 3. Q_SHF is ?
# 4. Q_PBL is purely **turbulent** (heat transfer from one altitude to another carried by small or "subgrid" parcels of air).
# 5. Q_cond is pur "chemical" (via condensation and latent heat release)
# 6. Q_cumulus is a mix of radiative and "chemical" forcing (via condensation)
# 7. Q_friction is arguably a version of **"conduction"**, as the kinetic energy of the wind gets turned into heat by the **physical contact** of molecules from micro-airmasses with different velocities.
#
# ### Third question (fourth bullet):
#
# Longwave heaing Q_LW is positive where more infrared photons arrive than leave. It is negative wherever more IR photons leave than arrive. Cloud effects can be understood using the concept that solid surfaces (both the Earth and cloud top and bottom) absorb all photons that strike them (no reflection), and emit more or less according to their local temperature as $\sigma T^4$. Since temperature T decreases with height in the troposphere, higher clouds will exhibit lower local temperatures and thus emit a lower amount of infrared radiation. This concept is utilized in infrared satellite imagery.

# %% [markdown]
# <hr style="height:2px;">
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise2"></a>
# ## Exercise 2: Find and load the LMT_5.4 bundle. Capture the storm image.

# %% [markdown]
# <div class="alert alert-info">
#     <b>Note</b>:
#      (If you like, you could do the Sandy version I made yesterday as a test, but it is bigger and slower to load.)
# </div>

# %%
# %reload_ext drilsdown
# Out:
# Starting IDV: /Applications/IDV_5.4u1/runIDV

# %%
# Your image 
# %makeImage

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise3"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 3</b>:
#      <ul>
#       <li>**Answer the LMT_5.4 questions a-k, using image captures and Markdown cells to make this notebook a readable document you are proud of.**
#
#       </li>
#
#        <li>To do this, **copy the boldface question for each part from the text**, and then write your answers in normal text, so that a reader of this notebook gets a coherent narrative.
#
#       </li>
#
#     </ul>
# </div>

# %%
# %makeImage -caption 1

# %%
# %makeImage -caption 2

# %%
# %makeImage -caption 3

# %% [markdown]
# ## Markdown answer for a):
#
#
# **a) Are the position of the cyclone and its fronts fairly well analyzed in the model felds? **
#
# Yes they are. MERRA analysis correctly places regions of positive/negative change of potential temperature with time (as a result of physical and dynamical processes) where they should be as a result of 1) our conceptual understanding of the anatomy of a midlatitude cyclone as well as 2) the orientation of cold/warm fronts depicted by temperature contour analysis and IR imagery (figure 1).
#
# **Does the model’s rainfall (and condensation heating) match what you would infer from the satellite imagery?**
#
# It does. MERRA's inferred precipitation distribution matches well with what can be confidently assumed to be precipitation denoted by IR imagery (in the region preceeding the cold front + the region slightly north extending east of the center of lowest surface pressure) (figure 2). This is also depicted in the distribution of positive physical heating contribution (red shading) as a result of condensation (figure 3).

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeMovie -caption Physical

# %% [markdown]
# ## Markdown answer for b):
#
#
# **Do some features in these displays correspond to each other? Which category of physical heating corresponds to MERRA’s prectot?**
#
# They do. Again, referring to figures 2 and 3, we see excellent collocation between regions of precipitation and regions of positive physical contribution to heating (as a result of condensation.)
#
# **What main diferences do you see in non-precipitating regions?**
#
# When examining the evolution through time, it can be seen that physical contributions to heating in non-precipitating regions increases from 15Z to 18Z rather consistently across the CONUS. One could argue that this is a result of diurnal heating as 15Z is roughly 10 AM CST (morning, low solar angle) whereas 18Z can be more or less considered the lower range of the "afternoon", corresponding to a higher solar angle and thus more incoming/absorbed shortwave solar radiation.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption Dynamical

# %% [markdown]
# ## Markdown answer for c):
#
#
# **Does it also have features that correspond to the pattern of MERRA’s prectot? Explain.**
#
# It does (as depicted above). It is likely a result of the presence of lift and associated adiabatic cooling that creates the precipitation formation seen in MERRA, along with the potential for column cooling as a result of falling precipitation (??). Lift can also result in horizontal advection (via continuity). As a result, the negative temperature forcing via dynamical processes may also be the result of horizontal cold air advection from the west (behind the cold front).

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption example

# %%
# %makeMovie

# %% [markdown]
# ## Markdown answer for d):
#
# ** Does this feld have much correspondence with MERRA’s prectot? Why or why not, in light of c) above?**
#
# To a degree, yes. As it combines the temperature time change as a result of both physical and dynamical processes, it would take into account 1) latent heat as a result of condensation, 2) adiabatic cooling/warming as a result of rising/sinking air, and 3) horizontal warm/cold air advection. The northern region of negative phy+dyn (dark blues) located to the east of the upper level low is likely an accumulation of large scale adiabatic cooling via positive vertical velocities as well as strong cold air advection (can infer via orientation of MSLP and Z500 contours). Lighter blues (less negative time tendency change of temperature) extend southward and are collocated with the region of "prectot" along the cold front. This is likely the result of adiabatic cooling via organized vertical motions as it becomes more pronounced through the animation as the IR image indicates more organized convection along the cold front.
#
# ** Loop between the two time steps. Using this logic, do the features in the net tendency phy+dyn explain the time evolution (motion and/or deepening) of the Z500 trough/cutof? Explain, with annotated image captures as needed for clarity**
#
# Based on Z500 contours, the upper level disturbance does not display any marked signs of intensification between timesteps as new closed contours do not appear and present ones only tighten slightly. It can be seen that the upper level disturbance does propagate eastward. This is logical as the region of net negative temperature tendency is located east of the geopotential height minimum. However, a slight overlap does occur, which may explain why the upper level disturbance intensifies ever so slightly as it propagates eastward.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption Analysis

# %%
# %makeImage

# %% [markdown]
# ## Markdown answer for e):
#
#
# **Is this feld “large” in magnitude? Compared to what, and why is that the right comparison in light of these considerations? Does it have features that correspond to MERRA’s prectot? What is your assessment of the general quality of the model’s analysis and physics in depicting this storm?**
#
# The field is relatively small in magnitude (good news for model accuracy!) when compared to the overall temperature forcing via both physical and dynamical processes. A few features of note would be the negative difference between analyzed temperature tendency and physical/dynamical temperature tendency relatively collocated with the region of strongest precipitation. This may be the result of the model underestimating the extent to which vertical motions/mixing/rain cooling cooled the column under such conditions (MERRA may struggle with resolving the extent of temperature tendencies in regions of vigorous precipitation/updraft?).

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption Cloudiness

# %% [markdown]
# ## Markdown answer for f):
#
# **Where in the cyclone do you see low, middle, and high cloudiness?**
#
# The lowest clouds (~1100 m) exist just to the east of what can be considered the center of circulation (including a bit of a buffer) and at the northern edge of the warm sector. This likely corresponds to the type of cloud formation that would occur at the edge of the warm sector, near the warm front. These low clouds are also likely associated with the outter region of lighter rain surrounding the most intense convection complex. The midlevel clouds (~6000 m) are likely related to the cloud field that typically exists surrounding the center of circulation, but not actually the result of precipitation-producing lift. The upper level clouds (~10,000 m) are likely associated with the upper level outflow associated with midlatitude cyclones and likely have some precipitating component to them.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption Longwave

# %%
# %makeImage -caption Net

# %% [markdown]
# ## Markdown answer for g):
#
#
# **Can you see the expected pattern of 1) heating at cloud bases and 2) cooling to space at cloud tops? Express the approximate magnitude of the heating in K per day, given that the displayed value is in K s−1. Which is more similar to the net radiative heating, the shortwave or the longwave?**
#
# Heating/cooling at cloud base/tops is evident in each each cloud layer when compared to the previous plot of cross-sectional cloudiness. Both occurences are most noticeable with regard to the highest clouds near the upper level outflow/precipitating region. This cloud deck, if it persisted for an entire day would be responsible for approximately 3.46 K of heating. Longwave heating much more similar to the net radiative heating as can be seen in comparison of the two images above. Shortwave heating (not shown) depicts widespread heating across the entire figure with maxima within each cloud region.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption Turbulent

# %%
# %makeImage -caption Friction

# %% [markdown]
# ## Markdown answer for h):
#
#
# **Where are they active? Why? About how big are their largest magnitudes in K day−1?**
#
# Both turbulence and friction result in net heating at the surface and in the boundary layer. This is logical as turbulence refers to the transport of surface thermal energy upward as a result of mixing and friction is the conversion of kinetic energy to thermal energy (and is almost exclusively confined to the near surface region). Within and just above the lowest cloud structure, turbulence actually results in a net cooling. This is likely the result of rain cooling/mixing as a result of turbulence caused by updrafts/downdrafts. The contribution of turbulence to net heating is approximately 4.3 K/day at its maximum while friction is responsible for approximately 3.4 K/day. The turbulent cooling within the low cloud base is comparable to that of its surface turbulent heating counterpart.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption Moist

# %%
# %makeImage -caption Clouds

# %% [markdown]
# ## Markdown answer for i):
#
#
# **How closely does dtdtmst correspond to the Cloudiness feld?**
#
# It matches very well (as is logical based on what we know about cloud formation as moist processes), as can be seen in the two figures above.
#
# **Where does dtdtmst have negative values? How can you understand those negative values in terms of moist processes (related to latent heat)?**
#
# The temperature tendency as a result of moist processes is negative in regions around the outskirts of the cloud/cloud base (predominantly on the east side of the thickest cloud/precipitation layer). This is potentially the result of evaporative cooling as a result of precipitation falling outside the main cloud column into a region of lower moisture content?

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption Comprehensive

# %% [markdown]
# ## Markdown answer for j):
#
#
# **Capture an image, and annotate features on it which are contributed by 1) moist, 2) radiative, and 3) turbulent processes, synthesizing your fndings above.**
#
# (My annotations were not showing well) The large maroon blob (most noticeable) along with the much smaller upward protrusion from the surface, are contributions to overall temperature tendency as a result of moist processes. They make up the overwhelming majority of the total tendency forcing. The maroon strip located near the surface across the entire cross-section is the contribution of turbulence to overall temperature tendency (along with a few subtle touches in and around the cloud structures as a result of turbulence via updrafts/downdrafts. The majority of negative forcing is the result of contributions from radiative cooling occuring throughout the atmopshere and most noticeably at the top of clouds. Some positive temperature tendency forcing near and around the cloud bases is the result of radiative heating.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %%
# %makeImage -caption Dynamical

# %%
# %makeImage -caption Analysis

# %% [markdown]
# ## Markdown answer for k):
#
#
# **Is the heat budget in this midlatitude cyclone primarily adiabatic?**
# To a degree, yes. Outside of perturbations to what could be considered the atmosphere "at rest", the atmosphere is mainly governed via motions that result in adiabatic temperature changes (represented by the large dominance of dark blues (adiabatic cooling) via rising motion and dark reds (adiabatic warming) via sinking motion. However, portions of the positive temperature forcing as a result of dynamical processes is diabatic in nature. That which is collocated with the cloud structures is likely the result of radiative forcing.
#
# **Is it safe to say that it is much smaller than the dominant term (dtdtdyn)? What would you say about its magnitude relative to some physical tendencies? What does this imply in terms of the quality of the model’s physics and dynamics processes?**
#
# It is safe to say that it is smaller than the dynamical term, but not necessarily as small as the question seems to be implying. It is quite comparable (in comparison to dynamical tendencies) in some regions. However, it struggles slightly near cloud layers (resulting in a net positive temperature tendency difference). This may be the result of the model's difficulties with resolving cloud radiative properties as well as it could?

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise4"></a>
# <div class="alert alert-success">
#     <b>EXERCISE 4</b>:
#      <ul>
#           <li>**Choose a storm case of your own. ** Maybe you did this last week. Choose carefully: you will revisit this as a project and perhaps make a Wikipedia page about it. If you like, choose a new one at this point.
#       </li>
#
#       <li>**Do the second optional exercise (loading LMT_5.4_MERRA_1979-2015 and moving the time and space box) for your case.**
#
#        <li>**Capture an image comparable to your favorite subsection above.**
#
#       </li>
#     </ul>
# </div>

# %%
# To use this feature, the IDV display must have its ID set to this name, in Properties. 
# %makeImage
# Out:
# ERROR:root:Line magic function `%makeImage` not found.

# %% [markdown]
# ## My case:
#
# #### I decided to study a storm that occurred (date and time, place), because (background info).
#
# The image above shows ...

# %%
# Wikipedia image
from IPython.display import Image
Image("an image URL goes here")

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# Upload your image to your GitHub area and put its URL into Blackboard.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">
